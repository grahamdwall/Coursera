# %% [markdown]
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/BQm_EV6i0_j80CQZ8vcLvw/SN-web-lightmode.png" width=300 height=300 />

# %% [markdown]
# ## Lab: Practical Application of Transpose Convolution
#
# **Estimated time needed: 30 minutes**
#
# This lab will guide you through creating, training, and evaluating models that use transpose convolution layers for tasks such as image reconstruction.
#
# ##### Learning objectives:
#
# By the end of this lab, you will:
#
# - Apply transpose convolution in practical scenarios using Keras.
#
# - Create, compile, train, and evaluate the model
#
# - Visualize the results
#
# ##### Prerequisites:
#
# - Basic understanding of Python programming
#
# - Familiarity with convolutional neural network (CNN) concepts
#
# - Keras and TensorFlow installed

# %% [markdown]
# #### Steps:
# **Step 1: Import Necessary Libraries**
#
# Before you start, make sure to import the required libraries: TensorFlow and Keras. Keras is included within TensorFlow as `tensorflow.keras`.

# %%
import warnings
warnings.simplefilter('ignore')

# !pip install tensorflow==2.16.2 

# !pip install matplotlib 
import tensorflow as tf 

from tensorflow.keras.models import Model 

from tensorflow.keras.layers import Input, Conv2D, Conv2DTranspose, UpSampling2D 

import numpy as np 

import matplotlib.pyplot as plt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 590.8/590.8 MB 20.7 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 164.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 128.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 62.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 54.7 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 63.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 48.6 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 58.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 58.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 115.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 138.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 91.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# **Explanation:**
#
#  `tensorflow` is the main library for machine learning in Python.
#
#   `Model, Input, Conv2D, and Conv2DTranspose` are used to create and manipulate the layers in your model.
#
#   `numpy` and `matplotlib` are used for data manipulation and visualization.
#
#
# **Step 2: Define the Input Layer**
#
# You need to define the input shape for your model. For simplicity, let's assume you are working with an input image of size 28x28 with 1 channel (grayscale).

# %%
input_layer = Input(shape=(28, 28, 1))

# %% [markdown]
# **Explanation:**
#
# `Input(shape=(28, 28, 1))` creates an input layer that expects 28x28 grayscale images.

# %% [markdown]
# **Step 3: Add convolutional and transpose convolutional layers**
#
# You will add a convolutional layer to extract features, followed by a transpose convolution layer to reconstruct the image.

# %%
conv_layer = Conv2D(filters=32, kernel_size=(3, 3), activation='relu', padding='same')(input_layer) 

transpose_conv_layer = Conv2DTranspose(filters=1, kernel_size=(3, 3), activation='sigmoid', padding='same')(conv_layer)

# %% [markdown]
# **Explanation:**
#
# `Conv2D(filters=32, kernel_size=(3, 3), activation='relu', padding='same')` creates a convolution layer with 32 filters.
#
# `Conv2DTranspose(filters=1, kernel_size=(3, 3), activation='sigmoid', padding='same')` creates a transpose convolution layer for reconstructing the image.
#
# **Step 4: Create the Model**
#
# Now, you will create the model by specifying the input and output layers.

# %%
model = Model(inputs=input_layer, outputs=transpose_conv_layer)

# %% [markdown]
# **Explanation:**
#
# `Model(inputs=input_layer, outputs=transpose_conv_layer)` creates a Keras model that connects the input layer to the output layer through the convolutional and transpose convolutional layers.
#
# **Step 5: Compile the Model**
#
# Before training the model, you need to compile it. You will specify the loss function, optimizer, and evaluation metrics.

# %%
model.compile(optimizer='adam', loss='mean_squared_error')

# %% [markdown]
# **Explanation:**
#
# - optimizer=`adam` specifies the Adam optimizer.
#
# - loss=`binary_crossentropy` specifies the binary cross-entropy loss function, suitable for binary pixel classification.

# %% [markdown]
# **Step 6: Train the Model**
#
# You can now train the model on some training data. For this example, let's assume X_train is our training input data.

# %%
# Generate synthetic training data 

X_train = np.random.rand(1000, 28, 28, 1) 

y_train = X_train # For reconstruction, the target is the input 

history = model.fit(X_train, y_train, epochs=10, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0824 - val_loss: 0.0646
# Epoch 2/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0592 - val_loss: 0.0413
# Epoch 3/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0360 - val_loss: 0.0216
# Epoch 4/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0183 - val_loss: 0.0104
# Epoch 5/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0089 - val_loss: 0.0055
# Epoch 6/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0050 - val_loss: 0.0036
# Epoch 7/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 8/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0027 - val_loss: 0.0023
# Epoch 9/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0022 - val_loss: 0.0020
# Epoch 10/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0020 - val_loss: 0.0018

# %% [markdown]
# **Explanation:**
#
# - X_train is a placeholder for your actual training data.
#
# - y_train is the same as X_train for image reconstruction.
#
# - model.fit trains the model for a specified number of epochs and batch size.
#
#
# **Step 7: Evaluate the Model**
#
# After training, you can evaluate the model on test data to see how well it performs.

# %%
 # Generate synthetic test data 

X_test = np.random.rand(200, 28, 28, 1) 

y_test = X_test 

loss = model.evaluate(X_test, y_test) 

print(f'Test loss: {loss}')
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0018
# Test loss: 0.00182020862121135

# %% [markdown]
# **Explanation:**
#
# `X_test` and `y_test` are placeholders for your actual test data.
#
# `model.evaluate` computes the loss of the model on test data. .
#
# **Step 8: Visualize the Results**
#
# To better understand the model's performance, let's visualize some reconstructed images.

# %%
# Predict on test data 
y_pred = model.predict(X_test) 

# Plot some sample images 

n = 10 # Number of samples to display 

plt.figure(figsize=(20, 4))

for i in range(n): 

    # Display original 
    ax = plt.subplot(2, n, i + 1) 
    plt.imshow(X_test[i].reshape(28, 28), cmap='gray')
    plt.title("Original") 
    plt.axis('off') 
    # Display reconstruction 
    ax = plt.subplot(2, n, i + 1 + n) 
    plt.imshow(y_pred[i].reshape(28, 28), cmap='gray')
    plt.title("Reconstructed")
    plt.axis('off')

plt.show()
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step

# %% [markdown]
# **Explanation:**
#
# `model.predict` generates predictions for the test data.
#
# `plt.imshow` visualizes the original and reconstructed images side by side for comparison.

# %% [markdown]
# ### Practice exercises

# %% [markdown]
# #### Exercise 1: Experiment with Different Kernel Sizes
#
# **Objective:** Understand the impact of different kernel sizes on the model's performance.
#
# **Instructions:**
# 1. Modify the kernel size of the `Conv2D` and `Conv2DTranspose` layers.
# 2. Recompile, train, and evaluate the model.
# 3. Observe and record the differences in performance.

# %%
import warnings
warnings.simplefilter('ignore')

# !pip install tensorflow==2.16.2 matplotlib

import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, Conv2DTranspose
import numpy as np
import matplotlib.pyplot as plt

# Function to train and evaluate the model with a given kernel size
def train_and_evaluate(kernel_size):
    print(f"\nTraining model with kernel size: {kernel_size}x{kernel_size}")

    # Define model
    input_layer = Input(shape=(28, 28, 1))
    conv_layer = Conv2D(filters=32, kernel_size=(kernel_size, kernel_size), activation='relu', padding='same')(input_layer)
    transpose_conv_layer = Conv2DTranspose(filters=1, kernel_size=(kernel_size, kernel_size), activation='sigmoid', padding='same')(conv_layer)
    
    model = Model(inputs=input_layer, outputs=transpose_conv_layer)
    model.compile(optimizer='adam', loss='mean_squared_error')

    # Generate synthetic training data
    X_train = np.random.rand(1000, 28, 28, 1)
    y_train = X_train  # Target is the input (autoencoder-style training)

    # Train model
    history = model.fit(X_train, y_train, epochs=10, batch_size=32, validation_split=0.2, verbose=1)

    # Generate synthetic test data
    X_test = np.random.rand(200, 28, 28, 1)
    y_test = X_test

    # Evaluate on test set
    loss = model.evaluate(X_test, y_test, verbose=1)
    print(f"Test loss for kernel size {kernel_size}x{kernel_size}: {loss}")

    # Predict on test data
    y_pred = model.predict(X_test)

    # Plot sample results
    n = 5  # Number of samples to display
    plt.figure(figsize=(12, 4))

    for i in range(n):
        # Original
        ax = plt.subplot(2, n, i + 1)
        plt.imshow(X_test[i].reshape(28, 28), cmap='gray')
        plt.title("Original")
        plt.axis('off')

        # Reconstructed
        ax = plt.subplot(2, n, i + 1 + n)
        plt.imshow(y_pred[i].reshape(28, 28), cmap='gray')
        plt.title(f"Reconstructed ({kernel_size}x{kernel_size})")
        plt.axis('off')

    plt.show()

    return loss

# Experiment with different kernel sizes
kernel_sizes = [3, 5, 7]
losses = {}

for k in kernel_sizes:
    losses[k] = train_and_evaluate(k)

# Plot test loss for different kernel sizes
plt.figure(figsize=(6, 4))
plt.plot(kernel_sizes, list(losses.values()), marker='o', linestyle='-')
plt.xlabel("Kernel Size")
plt.ylabel("Test Loss")
plt.title("Impact of Kernel Size on Test Loss")
plt.grid()
plt.show()
# Out:
# ...
#
# Training model with kernel size: 3x3
# Epoch 1/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0786 - val_loss: 0.0615
# Epoch 2/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0546 - val_loss: 0.0351
# Epoch 3/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0304 - val_loss: 0.0186
# Epoch 4/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0160 - val_loss: 0.0101
# Epoch 5/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0090 - val_loss: 0.0064
# Epoch 6/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0060 - val_loss: 0.0049
# Epoch 7/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0047 - val_loss: 0.0041
# Epoch 8/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0039 - val_loss: 0.0035
# Epoch 9/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0034 - val_loss: 0.0030
# Epoch 10/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0029 - val_loss: 0.0025
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0025
# ...

# %% [markdown]
# <details>
# <summary>Click here for solution</summary> </br>
#
# ```python
# from tensorflow.keras.layers import Dropout, Conv2D, Conv2DTranspose, Input
# from tensorflow.keras.models import Model
#
# # Define the input layer
# input_layer = Input(shape=(28, 28, 1))
#
# # Add convolutional and transpose convolutional layers with different kernel sizes
# conv_layer = Conv2D(filters=32, kernel_size=(5, 5), activation='relu', padding='same')(input_layer)
# transpose_conv_layer = Conv2DTranspose(filters=1, kernel_size=(5, 5), activation='sigmoid', padding='same')(conv_layer)
#
# # Create the model
# model = Model(inputs=input_layer, outputs=transpose_conv_layer)
#
# # Compile the model
# model.compile(optimizer='adam', loss='mean_squared_error')
#
# # Train the model
# history = model.fit(X_train, y_train, epochs=10, batch_size=32, validation_split=0.2)
#
# # Evaluate the model
# loss = model.evaluate(X_test, y_test)
# print(f'Test loss: {loss}')

# %% [markdown]
# #### Exercise 2: Add Dropout Layers
#
# **Objective:** Add dropout layers to prevent overfitting.
#
# **Instructions:**
# 1. Add dropout layers after the convolutional layer.
# 2. Set the dropout rate to 0.5.
# 3. Recompile, train, and evaluate the model.

# %%
import warnings
warnings.simplefilter('ignore')

# !pip install tensorflow==2.16.2 matplotlib

import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, Conv2DTranspose, Dropout
import numpy as np
import matplotlib.pyplot as plt

# Function to train and evaluate the model with dropout
def train_with_dropout(dropout_rate):
    print(f"\nTraining model with Dropout rate: {dropout_rate}")

    # Define the model with dropout
    input_layer = Input(shape=(28, 28, 1))
    conv_layer = Conv2D(filters=32, kernel_size=(3, 3), activation='relu', padding='same')(input_layer)
    dropout_layer = Dropout(dropout_rate)(conv_layer)  # Dropout to reduce overfitting
    transpose_conv_layer = Conv2DTranspose(filters=1, kernel_size=(3, 3), activation='sigmoid', padding='same')(dropout_layer)
    
    model = Model(inputs=input_layer, outputs=transpose_conv_layer)
    model.compile(optimizer='adam', loss='mean_squared_error')

    # Generate synthetic training data
    X_train = np.random.rand(1000, 28, 28, 1)
    y_train = X_train  # Target is the input (autoencoder-style training)

    # Train the model
    history = model.fit(X_train, y_train, epochs=10, batch_size=32, validation_split=0.2, verbose=1)

    # Generate synthetic test data
    X_test = np.random.rand(200, 28, 28, 1)
    y_test = X_test

    # Evaluate on test set
    loss = model.evaluate(X_test, y_test, verbose=1)
    print(f"Test loss with Dropout ({dropout_rate}): {loss}")

    # Predict on test data
    y_pred = model.predict(X_test)

    # Plot sample results
    n = 5  # Number of samples to display
    plt.figure(figsize=(12, 4))

    for i in range(n):
        # Original
        ax = plt.subplot(2, n, i + 1)
        plt.imshow(X_test[i].reshape(28, 28), cmap='gray')
        plt.title("Original")
        plt.axis('off')

        # Reconstructed
        ax = plt.subplot(2, n, i + 1 + n)
        plt.imshow(y_pred[i].reshape(28, 28), cmap='gray')
        plt.title(f"Reconstructed (Dropout {dropout_rate})")
        plt.axis('off')

    plt.show()

    return loss

# Train and evaluate the model with dropout (0.5)
dropout_rate = 0.5
test_loss = train_with_dropout(dropout_rate)
# Out:
# ...
#
# Training model with Dropout rate: 0.5
# Epoch 1/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0831 - val_loss: 0.0641
# Epoch 2/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0599 - val_loss: 0.0415
# Epoch 3/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0401 - val_loss: 0.0248
# Epoch 4/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0266 - val_loss: 0.0146
# Epoch 5/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0186 - val_loss: 0.0093
# Epoch 6/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0144 - val_loss: 0.0068
# Epoch 7/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0122 - val_loss: 0.0054
# Epoch 8/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0108 - val_loss: 0.0045
# Epoch 9/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0098 - val_loss: 0.0037
# Epoch 10/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0089 - val_loss: 0.0031
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0031
# ...

# %% [markdown]
# <details>
# <summary>Click here for solution</summary> </br>
#
# ```python
# from tensorflow.keras.layers import Dropout, Conv2D, Conv2DTranspose, Input
# from tensorflow.keras.models import Model
#
# # Define the input layer
# input_layer = Input(shape=(28, 28, 1))
#
# # Add convolutional, dropout, and transpose convolutional layers
# conv_layer = Conv2D(filters=32, kernel_size=(3, 3), activation='relu', padding='same')(input_layer)
# dropout_layer = Dropout(0.5)(conv_layer)
# transpose_conv_layer = Conv2DTranspose(filters=1, kernel_size=(3, 3), activation='sigmoid', padding='same')(dropout_layer)
#
# # Create the model
# model = Model(inputs=input_layer, outputs=transpose_conv_layer)
#
# # Compile the model
# model.compile(optimizer='adam', loss='mean_squared_error')
#
# # Train the model
# history = model.fit(X_train, y_train, epochs=10, batch_size=32, validation_split=0.2)
#
# # Evaluate the model
# loss = model.evaluate(X_test, y_test)
# print(f'Test loss: {loss}')

# %% [markdown]
# #### Exercise 3: Use Different Activation Functions
#
# **Objective:** Experiment with different activation functions and observe their impact on model performance.
#
# **Instructions:**
# 1. Change the activation function of the convolutional and transpose convolutional layers to `tanh`.
# 2. Recompile, train, and evaluate the model.

# %%
import warnings
warnings.simplefilter('ignore')

# !pip install tensorflow==2.16.2 matplotlib

import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, Conv2DTranspose
import numpy as np
import matplotlib.pyplot as plt

# Function to train and evaluate the model with tanh activation
def train_with_activation(activation_function):
    print(f"\nTraining model with Activation Function: {activation_function}")

    # Define the model with tanh activation
    input_layer = Input(shape=(28, 28, 1))
    conv_layer = Conv2D(filters=32, kernel_size=(3, 3), activation=activation_function, padding='same')(input_layer)
    transpose_conv_layer = Conv2DTranspose(filters=1, kernel_size=(3, 3), activation=activation_function, padding='same')(conv_layer)
    
    model = Model(inputs=input_layer, outputs=transpose_conv_layer)
    model.compile(optimizer='adam', loss='mean_squared_error')

    # Generate synthetic training data
    X_train = np.random.rand(1000, 28, 28, 1)
    y_train = X_train  # Target is the input (autoencoder-style training)

    # Train the model
    history = model.fit(X_train, y_train, epochs=10, batch_size=32, validation_split=0.2, verbose=1)

    # Generate synthetic test data
    X_test = np.random.rand(200, 28, 28, 1)
    y_test = X_test

    # Evaluate on test set
    loss = model.evaluate(X_test, y_test, verbose=1)
    print(f"Test loss with Activation ({activation_function}): {loss}")

    # Predict on test data
    y_pred = model.predict(X_test)

    # Plot sample results
    n = 5  # Number of samples to display
    plt.figure(figsize=(12, 4))

    for i in range(n):
        # Original
        ax = plt.subplot(2, n, i + 1)
        plt.imshow(X_test[i].reshape(28, 28), cmap='gray')
        plt.title("Original")
        plt.axis('off')

        # Reconstructed
        ax = plt.subplot(2, n, i + 1 + n)
        plt.imshow(y_pred[i].reshape(28, 28), cmap='gray')
        plt.title(f"Reconstructed ({activation_function})")
        plt.axis('off')

    plt.show()

    return loss

# Train and evaluate the model with tanh activation
activation_function = 'tanh'
test_loss = train_with_activation(activation_function)
# Out:
# ...
#
# Training model with Activation Function: tanh
# Epoch 1/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0687 - val_loss: 0.0273
# Epoch 2/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0207 - val_loss: 0.0087
# Epoch 3/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0075 - val_loss: 0.0053
# Epoch 4/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0050 - val_loss: 0.0045
# Epoch 5/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0044 - val_loss: 0.0042
# Epoch 6/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0041 - val_loss: 0.0040
# Epoch 7/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 8/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 9/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 10/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0037 - val_loss: 0.0036
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0036
# ...

# %% [markdown]
# <details>
# <summary>Click here for solution</summary> </br>
#
# ```python
#
# from tensorflow.keras.layers import Conv2D, Conv2DTranspose, Input
# from tensorflow.keras.models import Model
#
# # Define the input layer
# input_layer = Input(shape=(28, 28, 1))
#
# # Add convolutional and transpose convolutional layers with different activation functions
# conv_layer = Conv2D(filters=32, kernel_size=(3, 3), activation='tanh', padding='same')(input_layer)
# transpose_conv_layer = Conv2DTranspose(filters=1, kernel_size=(3, 3), activation='tanh', padding='same')(conv_layer)
#
# # Create the model
# model = Model(inputs=input_layer, outputs=transpose_conv_layer)
#
# # Compile the model
# model.compile(optimizer='adam', loss='mean_squared_error')
#
# # Train the model
# history = model.fit(X_train, y_train, epochs=10, batch_size=32, validation_split=0.2)
#
# # Evaluate the model
# loss = model.evaluate(X_test, y_test)
# print(f'Test loss: {loss}')

# %% [markdown]
# ### Conclusion:
#
# By completing this lab, you have successfully created, trained, and evaluated a simple neural network model using transpose convolution for image reconstruction. This exercise provided hands-on experience with Keras and practical applications of transpose convolution layers. Continue experimenting with different architectures and datasets to deepen your understanding and skills in deep learning with Keras.

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
