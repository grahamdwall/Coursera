# %% [markdown]
# <a href="https://cognitiveclass.ai"><img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DL0101EN-SkillsNetwork/images/IDSN-logo.png" width="400"> </a>
#
# # Regression Models with Keras
#
# Estimated time needed: **45** mins

# %% [markdown]
# ## Introduction

# %% [markdown]
# As we discussed in the videos, despite the popularity of more powerful libraries such as PyToch and TensorFlow, they are not easy to use and have a steep learning curve. So, for people who are just starting to learn deep learning, there is no better library to use other than the Keras library.
#
# Keras is a high-level API for building deep learning models. It has gained favor for its ease of use and syntactic simplicity facilitating fast development. As you will see in this lab and the other labs in this course, building a very complex deep learning network can be achieved with Keras with only few lines of code. You will appreciate Keras even more, once you learn how to build deep models using PyTorch and TensorFlow in the other courses.
#
# So, in this lab, you will learn how to use the Keras library to build a regression model.

# %% [markdown]
# ## Objectives for this Notebook
# * How to use the Keras library to build a regression model
# * Download and clean the data set
# * Build a neural network
# * Train and test the network

# %% [markdown]
# ## Table of Contents
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# <font size = 3>
#
# 1. <a href="#item31">Download and Clean the Data Set</a>
# 2. <a href="#item32">Import Keras Packages</a>
# 3. <a href="#item33">Build a Neural Network</a>
# 4. <a href="#item34">Train and Test the Network</a>
#
# </font>
# </div>

# %% [markdown]
# <a id="item31"></a>

# %% [markdown]
# ## Download and Clean the  Data Set

# %% [markdown]
# Let's start by importing the <em>pandas</em> and the Numpy libraries.

# %%
# All Libraries required for this lab are listed below. 

# !pip install numpy==2.0.2
# !pip install pandas==2.2.2
# !pip install tensorflow_cpu==2.18.0
# Out:
# Collecting numpy==2.0.2
#   Downloading numpy-2.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Downloading numpy-2.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (19.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.2/19.2 MB 107.7 MB/s eta 0:00:00
# Installing collected packages: numpy
# Successfully installed numpy-2.0.2
# Collecting pandas==2.2.2
#   Downloading pandas-2.2.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.26.0 in /opt/conda/lib/python3.12/site-packages (from pandas==2.2.2) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from pandas==2.2.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas==2.2.2) (2024.2)
# Collecting tzdata>=2022.7 (from pandas==2.2.2)
#   Downloading tzdata-2025.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas==2.2.2) (1.17.0)
# Downloading pandas-2.2.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 111.7 MB/s eta 0:00:00
# Downloading tzdata-2025.1-py2.py3-none-any.whl (346 kB)
# Installing collected packages: tzdata, pandas
# Successfully installed pandas-2.2.2 tzdata-2025.1
# Collecting tensorflow_cpu==2.18.0
#   Downloading tensorflow_cpu-2.18.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Collecting absl-py>=1.0.0 (from tensorflow_cpu==2.18.0)
#   Downloading absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow_cpu==2.18.0)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=24.3.25 (from tensorflow_cpu==2.18.0)
#   Downloading flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow_cpu==2.18.0)
#   Downloading gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow_cpu==2.18.0)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow_cpu==2.18.0)
#   Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl.metadata (5.2 kB)
# Collecting opt-einsum>=2.3.2 (from tensorflow_cpu==2.18.0)
#   Downloading opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.12/site-packages (from tensorflow_cpu==2.18.0) (24.2)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 (from tensorflow_cpu==2.18.0)
#   Downloading protobuf-5.29.3-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow_cpu==2.18.0) (2.32.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.12/site-packages (from tensorflow_cpu==2.18.0) (75.8.0)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow_cpu==2.18.0) (1.17.0)
# Collecting termcolor>=1.1.0 (from tensorflow_cpu==2.18.0)
#   Downloading termcolor-2.5.0-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/conda/lib/python3.12/site-packages (from tensorflow_cpu==2.18.0) (4.12.2)
# Collecting wrapt>=1.11.0 (from tensorflow_cpu==2.18.0)
#   Downloading wrapt-1.17.2-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.4 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow_cpu==2.18.0)
#   Downloading grpcio-1.70.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.9 kB)
# Collecting tensorboard<2.19,>=2.18 (from tensorflow_cpu==2.18.0)
#   Downloading tensorboard-2.18.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting keras>=3.5.0 (from tensorflow_cpu==2.18.0)
#   Downloading keras-3.8.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow_cpu==2.18.0) (2.0.2)
# Collecting h5py>=3.11.0 (from tensorflow_cpu==2.18.0)
#   Downloading h5py-3.13.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.5 kB)
# Collecting ml-dtypes<0.5.0,>=0.4.0 (from tensorflow_cpu==2.18.0)
#   Downloading ml_dtypes-0.4.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/conda/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow_cpu==2.18.0) (0.45.1)
# Collecting rich (from keras>=3.5.0->tensorflow_cpu==2.18.0)
#   Downloading rich-13.9.4-py3-none-any.whl.metadata (18 kB)
# Collecting namex (from keras>=3.5.0->tensorflow_cpu==2.18.0)
#   Downloading namex-0.0.8-py3-none-any.whl.metadata (246 bytes)
# Collecting optree (from keras>=3.5.0->tensorflow_cpu==2.18.0)
#   Downloading optree-0.14.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (47 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow_cpu==2.18.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow_cpu==2.18.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow_cpu==2.18.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow_cpu==2.18.0) (2024.12.14)
# Collecting markdown>=2.6.8 (from tensorboard<2.19,>=2.18->tensorflow_cpu==2.18.0)
#   Downloading Markdown-3.7-py3-none-any.whl.metadata (7.0 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard<2.19,>=2.18->tensorflow_cpu==2.18.0)
#   Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard<2.19,>=2.18->tensorflow_cpu==2.18.0)
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow_cpu==2.18.0) (3.0.2)
# Collecting markdown-it-py>=2.2.0 (from rich->keras>=3.5.0->tensorflow_cpu==2.18.0)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.12/site-packages (from rich->keras>=3.5.0->tensorflow_cpu==2.18.0) (2.19.1)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow_cpu==2.18.0)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading tensorflow_cpu-2.18.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (230.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 230.3/230.3 MB 47.9 MB/s eta 0:00:0000:0100:01
# Downloading absl_py-2.1.0-py3-none-any.whl (133 kB)
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Downloading gast-0.6.0-py3-none-any.whl (21 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Downloading grpcio-1.70.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 118.8 MB/s eta 0:00:00
# Downloading h5py-3.13.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 49.6 MB/s eta 0:00:00
# Downloading keras-3.8.0-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 64.6 MB/s eta 0:00:00
# Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl (24.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 48.1 MB/s eta 0:00:00:00:01
# Downloading ml_dtypes-0.4.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 59.4 MB/s eta 0:00:00
# Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Downloading protobuf-5.29.3-cp38-abi3-manylinux2014_x86_64.whl (319 kB)
# Downloading tensorboard-2.18.0-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 53.1 MB/s eta 0:00:00
# Downloading termcolor-2.5.0-py3-none-any.whl (7.8 kB)
# Downloading wrapt-1.17.2-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (89 kB)
# Downloading Markdown-3.7-py3-none-any.whl (106 kB)
# Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 62.3 MB/s eta 0:00:00
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Downloading namex-0.0.8-py3-none-any.whl (5.8 kB)
# Downloading optree-0.14.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (400 kB)
# Downloading rich-13.9.4-py3-none-any.whl (242 kB)
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: namex, libclang, flatbuffers, wrapt, werkzeug, termcolor, tensorboard-data-server, protobuf, optree, opt-einsum, ml-dtypes, mdurl, markdown, h5py, grpcio, google-pasta, gast, astunparse, absl-py, tensorboard, markdown-it-py, rich, keras, tensorflow_cpu
# Successfully installed absl-py-2.1.0 astunparse-1.6.3 flatbuffers-25.2.10 gast-0.6.0 google-pasta-0.2.0 grpcio-1.70.0 h5py-3.13.0 keras-3.8.0 libclang-18.1.1 markdown-3.7 markdown-it-py-3.0.0 mdurl-0.1.2 ml-dtypes-0.4.1 namex-0.0.8 opt-einsum-3.4.0 optree-0.14.0 protobuf-5.29.3 rich-13.9.4 tensorboard-2.18.0 tensorboard-data-server-0.7.2 tensorflow_cpu-2.18.0 termcolor-2.5.0 werkzeug-3.1.3 wrapt-1.17.2

# %% [markdown]
# ##### To use Keras, you will also need to install a backend framework – such as TensorFlow.
#
# If you install TensorFlow 2.16 or above, it will install Keras by default.
#
# We are using the CPU version of tensorflow since we are dealing with smaller datasets.
# You may install the GPU version of tensorflow on your machine to accelarate the processing of larger datasets

# %%
import pandas as pd
import numpy as np
import keras

import warnings
warnings.simplefilter('ignore', FutureWarning)
# Out:
# 2025-02-26 16:16:01.421645: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-02-26 16:16:01.476342: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# We will be playing around with the same dataset that we used in the videos.
#
# <strong>The dataset is about the compressive strength of different samples of concrete based on the volumes of the different ingredients that were used to make them. Ingredients include:</strong>
#
# * Cement
# * Blast furnace slag
# * Fly ash
# * Water
# * Superplasticizer
# * Coarse aggregate
# * Fine aggregate

# %% [markdown]
# Let's download the data and read it into a <em>pandas</em> dataframe.

# %%
filepath='https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0101EN/labs/data/concrete_data.csv'
concrete_data = pd.read_csv(filepath)

concrete_data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %% [markdown]
# So the first concrete sample has 540 cubic meter of cement, 0 cubic meter of blast furnace slag, 0 cubic meter of fly ash, 162 cubic meter of water, 2.5 cubic meter of superplaticizer, 1040 cubic meter of coarse aggregate, 676 cubic meter of fine aggregate. Such a concrete mix which is 28 days old, has a compressive strength of 79.99 MPa.

# %% [markdown]
# #### Let's check how many data points we have

# %%
concrete_data.shape
# Out:
# (1030, 9)

# %% [markdown]
# So, there are approximately 1000 samples to train our model on. Because of the few samples, we have to be careful not to overfit the training data.

# %% [markdown]
# Let's check the dataset for any missing values.

# %%
concrete_data.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# 25%            0.000000        932.000000      730.950000     7.000000
# 50%            6.400000        968.000000      779.500000    28.000000
# 75%           10.200000       1029.400000      824.000000    56.000000
# max           32.200000       1145.000000      992.600000   365.000000
#
#           Strength
# count  1030.000000
# mean     35.817961
# std      16.705742
# min       2.330000
# 25%      23.710000
# 50%      34.445000
# 75%      46.135000
# max      82.600000

# %%
concrete_data.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %% [markdown]
# The data looks very clean and is ready to be used to build our model.

# %% [markdown]
# #### Split data into predictors and target

# %% [markdown]
# The target variable in this problem is the concrete sample strength. Therefore, our predictors will be all the other columns.

# %%
concrete_data_columns = concrete_data.columns

# %%
predictors = concrete_data[concrete_data_columns[concrete_data_columns != 'Strength']] # all columns except Strength
target = concrete_data['Strength'] # Strength column

# %% [markdown]
# <a id="item2"></a>

# %% [markdown]
# Let's do a quick sanity check of the predictors and the target dataframes.

# %%
predictors.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age
# 0            1040.0           676.0   28
# 1            1055.0           676.0   28
# 2             932.0           594.0  270
# 3             932.0           594.0  365
# 4             978.4           825.5  360

# %%
target.head()
# Out:
# 0    79.99
# 1    61.89
# 2    40.27
# 3    41.05
# 4    44.30
# Name: Strength, dtype: float64

# %% [markdown]
# Finally, the last step is to normalize the data by substracting the mean and dividing by the standard deviation.

# %%
predictors_norm = (predictors - predictors.mean()) / predictors.std()
predictors_norm.head()
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age
# 0          0.862735       -1.217079 -0.279597
# 1          1.055651       -1.217079 -0.279597
# 2         -0.526262       -2.239829  3.551340
# 3         -0.526262       -2.239829  5.055221
# 4          0.070492        0.647569  4.976069

# %% [markdown]
# Let's save the number of predictors to *n_cols* since we will need this number when building our network.

# %%
n_cols = predictors_norm.shape[1] # number of predictors

# %% [markdown]
# <a id="item1"></a>

# %% [markdown]
# <a id='item32'></a>

# %% [markdown]
# ##  Import Keras Packages
#
# ##### Let's import the rest of the packages from the Keras library that we will need to build our regression model.

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Input

# %% [markdown]
# <a id='item33'></a>

# %% [markdown]
# ## Build a Neural Network

# %% [markdown]
# Let's define a function that defines our regression model for us so that we can conveniently call it to create our model.

# %%
# define regression model
def regression_model():
    # create model
    model = Sequential()
    model.add(Input(shape=(n_cols,)))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(1))
    
    # compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %% [markdown]
# The above function create a model that has two hidden layers, each of 50 hidden units.

# %% [markdown]
# <a id="item4"></a>

# %% [markdown]
# ## Train and Test the Network

# %% [markdown]
# Let's call the function now to create our model.

# %%
# build the model
model = regression_model()

# %% [markdown]
# Next, we will train and test the model at the same time using the *fit* method. We will leave out 30% of the data for validation and we will train the model for 100 epochs.

# %%
# fit the model
model.fit(predictors_norm, target, validation_split=0.3, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 23/23 - 2s - 67ms/step - loss: 1633.5566 - val_loss: 1125.4288
# Epoch 2/100
# 23/23 - 0s - 8ms/step - loss: 1491.8021 - val_loss: 985.9176
# Epoch 3/100
# 23/23 - 0s - 14ms/step - loss: 1244.0115 - val_loss: 764.2280
# Epoch 4/100
# 23/23 - 0s - 8ms/step - loss: 884.0518 - val_loss: 503.3524
# Epoch 5/100
# 23/23 - 0s - 10ms/step - loss: 514.4304 - val_loss: 292.8847
# Epoch 6/100
# 23/23 - 0s - 8ms/step - loss: 297.8842 - val_loss: 193.9141
# Epoch 7/100
# 23/23 - 0s - 9ms/step - loss: 244.1577 - val_loss: 162.1433
# Epoch 8/100
# 23/23 - 0s - 7ms/step - loss: 221.5343 - val_loss: 158.4063
# Epoch 9/100
# 23/23 - 0s - 8ms/step - loss: 206.5157 - val_loss: 150.5592
# Epoch 10/100
# 23/23 - 0s - 10ms/step - loss: 196.0214 - val_loss: 149.3039
# Epoch 11/100
# 23/23 - 0s - 14ms/step - loss: 188.4297 - val_loss: 144.3010
# Epoch 12/100
# 23/23 - 0s - 8ms/step - loss: 181.7217 - val_loss: 146.1083
# Epoch 13/100
# 23/23 - 0s - 15ms/step - loss: 176.3107 - val_loss: 145.1591
# Epoch 14/100
# 23/23 - 0s - 12ms/step - loss: 172.4615 - val_loss: 143.5259
# Epoch 15/100
# 23/23 - 0s - 9ms/step - loss: 168.1859 - val_loss: 141.5392
# Epoch 16/100
# 23/23 - 0s - 8ms/step - loss: 164.9891 - val_loss: 140.4875
# Epoch 17/100
# 23/23 - 0s - 9ms/step - loss: 161.3115 - val_loss: 141.7964
# Epoch 18/100
# 23/23 - 0s - 9ms/step - loss: 158.7491 - val_loss: 140.2347
# Epoch 19/100
# 23/23 - 0s - 8ms/step - loss: 156.1083 - val_loss: 142.8650
# Epoch 20/100
# 23/23 - 0s - 7ms/step - loss: 154.0747 - val_loss: 140.2253
# Epoch 21/100
# 23/23 - 0s - 7ms/step - loss: 151.7036 - val_loss: 143.0598
# Epoch 22/100
# 23/23 - 0s - 7ms/step - loss: 149.9487 - val_loss: 141.8665
# Epoch 23/100
# 23/23 - 0s - 7ms/step - loss: 147.3871 - val_loss: 140.1280
# Epoch 24/100
# 23/23 - 0s - 7ms/step - loss: 146.1687 - val_loss: 142.4559
# Epoch 25/100
# 23/23 - 0s - 7ms/step - loss: 144.6420 - val_loss: 143.1749
# Epoch 26/100
# 23/23 - 0s - 15ms/step - loss: 143.0074 - val_loss: 141.9686
# Epoch 27/100
# 23/23 - 0s - 8ms/step - loss: 141.1316 - val_loss: 141.1676
# Epoch 28/100
# 23/23 - 0s - 9ms/step - loss: 139.6164 - val_loss: 143.8420
# Epoch 29/100
# 23/23 - 0s - 8ms/step - loss: 138.4054 - val_loss: 145.1741
# Epoch 30/100
# 23/23 - 0s - 8ms/step - loss: 137.8722 - val_loss: 142.9821
# Epoch 31/100
# 23/23 - 0s - 8ms/step - loss: 136.2196 - val_loss: 143.2614
# Epoch 32/100
# 23/23 - 0s - 10ms/step - loss: 134.9050 - val_loss: 147.1455
# Epoch 33/100
# 23/23 - 0s - 9ms/step - loss: 133.8517 - val_loss: 145.5068
# Epoch 34/100
# 23/23 - 0s - 8ms/step - loss: 132.1313 - val_loss: 147.8443
# Epoch 35/100
# 23/23 - 0s - 8ms/step - loss: 130.7804 - val_loss: 149.9411
# Epoch 36/100
# 23/23 - 0s - 9ms/step - loss: 129.9696 - val_loss: 148.3590
# Epoch 37/100
# 23/23 - 0s - 7ms/step - loss: 128.1483 - val_loss: 145.6784
# Epoch 38/100
# 23/23 - 0s - 13ms/step - loss: 127.3669 - val_loss: 146.1182
# Epoch 39/100
# 23/23 - 0s - 8ms/step - loss: 125.8336 - val_loss: 147.7854
# Epoch 40/100
# 23/23 - 0s - 7ms/step - loss: 124.5001 - val_loss: 146.7600
# Epoch 41/100
# 23/23 - 0s - 7ms/step - loss: 122.6263 - val_loss: 147.1454
# Epoch 42/100
# 23/23 - 0s - 7ms/step - loss: 121.9722 - val_loss: 146.5296
# Epoch 43/100
# 23/23 - 0s - 7ms/step - loss: 120.8855 - val_loss: 147.1808
# Epoch 44/100
# 23/23 - 0s - 8ms/step - loss: 118.0272 - val_loss: 145.6671
# Epoch 45/100
# 23/23 - 0s - 7ms/step - loss: 116.4711 - val_loss: 147.4993
# Epoch 46/100
# 23/23 - 0s - 9ms/step - loss: 115.2543 - val_loss: 142.0105
# Epoch 47/100
# 23/23 - 0s - 9ms/step - loss: 113.7499 - val_loss: 149.5914
# Epoch 48/100
# 23/23 - 0s - 14ms/step - loss: 111.7121 - val_loss: 144.8200
# Epoch 49/100
# 23/23 - 0s - 10ms/step - loss: 110.2941 - val_loss: 139.7466
# Epoch 50/100
# 23/23 - 0s - 9ms/step - loss: 109.3120 - val_loss: 146.8144
# Epoch 51/100
# 23/23 - 0s - 8ms/step - loss: 106.5168 - val_loss: 140.9151
# Epoch 52/100
# 23/23 - 0s - 7ms/step - loss: 104.8450 - val_loss: 138.7309
# Epoch 53/100
# 23/23 - 0s - 9ms/step - loss: 102.8377 - val_loss: 142.5710
# Epoch 54/100
# 23/23 - 0s - 7ms/step - loss: 101.4065 - val_loss: 130.8176
# Epoch 55/100
# 23/23 - 0s - 9ms/step - loss: 99.5254 - val_loss: 139.0538
# Epoch 56/100
# 23/23 - 0s - 7ms/step - loss: 96.7102 - val_loss: 134.9941
# Epoch 57/100
# 23/23 - 0s - 8ms/step - loss: 94.4713 - val_loss: 136.2247
# Epoch 58/100
# 23/23 - 0s - 8ms/step - loss: 92.3777 - val_loss: 131.2694
# Epoch 59/100
# 23/23 - 0s - 8ms/step - loss: 90.6210 - val_loss: 131.9186
# Epoch 60/100
# 23/23 - 0s - 8ms/step - loss: 88.8297 - val_loss: 134.8318
# Epoch 61/100
# 23/23 - 0s - 7ms/step - loss: 86.4144 - val_loss: 131.7886
# Epoch 62/100
# 23/23 - 0s - 9ms/step - loss: 84.0692 - val_loss: 126.6821
# Epoch 63/100
# 23/23 - 0s - 8ms/step - loss: 81.9890 - val_loss: 126.3945
# Epoch 64/100
# 23/23 - 0s - 9ms/step - loss: 80.3922 - val_loss: 131.2530
# Epoch 65/100
# 23/23 - 0s - 8ms/step - loss: 78.0324 - val_loss: 127.8419
# Epoch 66/100
# 23/23 - 0s - 9ms/step - loss: 76.0399 - val_loss: 124.7068
# Epoch 67/100
# 23/23 - 0s - 9ms/step - loss: 74.2521 - val_loss: 125.8624
# Epoch 68/100
# 23/23 - 0s - 8ms/step - loss: 71.7948 - val_loss: 128.0440
# Epoch 69/100
# 23/23 - 0s - 7ms/step - loss: 70.7631 - val_loss: 134.2115
# Epoch 70/100
# 23/23 - 0s - 7ms/step - loss: 69.8446 - val_loss: 120.6901
# Epoch 71/100
# 23/23 - 0s - 8ms/step - loss: 66.8899 - val_loss: 133.6295
# Epoch 72/100
# 23/23 - 0s - 8ms/step - loss: 66.5744 - val_loss: 118.5788
# Epoch 73/100
# 23/23 - 0s - 7ms/step - loss: 65.0500 - val_loss: 125.9483
# Epoch 74/100
# 23/23 - 0s - 8ms/step - loss: 61.7790 - val_loss: 121.5272
# Epoch 75/100
# 23/23 - 0s - 7ms/step - loss: 60.5829 - val_loss: 126.3482
# Epoch 76/100
# 23/23 - 0s - 8ms/step - loss: 59.3300 - val_loss: 126.4445
# Epoch 77/100
# 23/23 - 0s - 8ms/step - loss: 58.1741 - val_loss: 122.6393
# Epoch 78/100
# 23/23 - 0s - 8ms/step - loss: 56.8129 - val_loss: 120.8499
# Epoch 79/100
# 23/23 - 0s - 8ms/step - loss: 55.7058 - val_loss: 121.3882
# Epoch 80/100
# 23/23 - 0s - 9ms/step - loss: 54.5021 - val_loss: 124.5181
# Epoch 81/100
# 23/23 - 0s - 12ms/step - loss: 53.3224 - val_loss: 126.9966
# Epoch 82/100
# 23/23 - 0s - 12ms/step - loss: 51.9899 - val_loss: 125.3987
# Epoch 83/100
# 23/23 - 0s - 9ms/step - loss: 50.8871 - val_loss: 125.6785
# Epoch 84/100
# 23/23 - 0s - 8ms/step - loss: 49.8937 - val_loss: 121.2156
# Epoch 85/100
# 23/23 - 0s - 8ms/step - loss: 49.0130 - val_loss: 129.0779
# Epoch 86/100
# 23/23 - 0s - 8ms/step - loss: 47.6862 - val_loss: 120.7224
# Epoch 87/100
# 23/23 - 0s - 7ms/step - loss: 47.1497 - val_loss: 119.8779
# Epoch 88/100
# 23/23 - 0s - 7ms/step - loss: 45.9363 - val_loss: 134.4691
# Epoch 89/100
# 23/23 - 0s - 14ms/step - loss: 45.8948 - val_loss: 123.4361
# Epoch 90/100
# 23/23 - 0s - 7ms/step - loss: 44.7983 - val_loss: 125.5187
# Epoch 91/100
# 23/23 - 0s - 7ms/step - loss: 43.8659 - val_loss: 127.2984
# Epoch 92/100
# 23/23 - 0s - 8ms/step - loss: 43.2699 - val_loss: 126.0566
# Epoch 93/100
# 23/23 - 0s - 14ms/step - loss: 43.9476 - val_loss: 117.6543
# Epoch 94/100
# 23/23 - 0s - 9ms/step - loss: 42.5516 - val_loss: 119.6695
# Epoch 95/100
# 23/23 - 0s - 15ms/step - loss: 41.2739 - val_loss: 130.2575
# Epoch 96/100
# 23/23 - 0s - 8ms/step - loss: 40.3418 - val_loss: 128.2565
# Epoch 97/100
# 23/23 - 0s - 8ms/step - loss: 40.0954 - val_loss: 133.5926
# Epoch 98/100
# 23/23 - 0s - 8ms/step - loss: 39.3763 - val_loss: 128.5342
# Epoch 99/100
# 23/23 - 0s - 9ms/step - loss: 38.7302 - val_loss: 126.5584
# Epoch 100/100
# 23/23 - 0s - 9ms/step - loss: 39.0841 - val_loss: 126.6339

# %% [markdown]
# <strong>You can refer to this [link](https://keras.io/models/sequential/) to learn about other functions that you can use for prediction or evaluation.</strong>

# %% [markdown]
# Feel free to vary the following and note what impact each change has on the model's performance:
#
# 1. Increase or decreate number of neurons in hidden layers
# 2. Add more hidden layers
# 3. Increase number of epochs

# %% [markdown]
# <h3>Practice Exercise 1</h3>

# %% [markdown]
# Now using the same dateset,try to recreate regression model featuring five hidden layers, each with 50 nodes and ReLU activation functions, a single output layer, optimized using the Adam optimizer.

# %%
# define regression model
def regression_model():
    # create model
    model = Sequential()
    model.add(Input(shape=(n_cols,)))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(1))
    
    # compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# build the model
model = regression_model()

# fit the model
model.fit(predictors_norm, target, validation_split=0.3, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 23/23 - 2s - 104ms/step - loss: 1649.5886 - val_loss: 1086.5133
# Epoch 2/100
# 23/23 - 0s - 10ms/step - loss: 1142.5811 - val_loss: 261.0480
# Epoch 3/100
# 23/23 - 0s - 11ms/step - loss: 337.4972 - val_loss: 200.2476
# Epoch 4/100
# 23/23 - 0s - 11ms/step - loss: 220.8637 - val_loss: 192.3393
# Epoch 5/100
# 23/23 - 0s - 10ms/step - loss: 196.3423 - val_loss: 172.6434
# Epoch 6/100
# 23/23 - 0s - 10ms/step - loss: 181.7062 - val_loss: 185.0460
# Epoch 7/100
# 23/23 - 0s - 9ms/step - loss: 167.5810 - val_loss: 164.3110
# Epoch 8/100
# 23/23 - 0s - 10ms/step - loss: 152.7362 - val_loss: 157.5249
# Epoch 9/100
# 23/23 - 0s - 10ms/step - loss: 142.6866 - val_loss: 148.4862
# Epoch 10/100
# 23/23 - 0s - 11ms/step - loss: 130.0679 - val_loss: 142.7022
# Epoch 11/100
# 23/23 - 0s - 10ms/step - loss: 114.0935 - val_loss: 133.4109
# Epoch 12/100
# 23/23 - 0s - 10ms/step - loss: 100.8486 - val_loss: 142.1400
# Epoch 13/100
# 23/23 - 0s - 10ms/step - loss: 84.8872 - val_loss: 125.3608
# Epoch 14/100
# 23/23 - 0s - 10ms/step - loss: 74.3540 - val_loss: 141.1640
# Epoch 15/100
# 23/23 - 0s - 12ms/step - loss: 63.9821 - val_loss: 126.7942
# Epoch 16/100
# 23/23 - 0s - 11ms/step - loss: 58.7500 - val_loss: 140.4919
# Epoch 17/100
# 23/23 - 0s - 10ms/step - loss: 54.2699 - val_loss: 117.4009
# Epoch 18/100
# 23/23 - 0s - 10ms/step - loss: 49.4031 - val_loss: 136.8973
# Epoch 19/100
# 23/23 - 0s - 11ms/step - loss: 47.3808 - val_loss: 151.2404
# Epoch 20/100
# 23/23 - 0s - 9ms/step - loss: 43.8645 - val_loss: 126.1017
# Epoch 21/100
# 23/23 - 0s - 9ms/step - loss: 42.2927 - val_loss: 140.5823
# Epoch 22/100
# 23/23 - 0s - 9ms/step - loss: 40.3567 - val_loss: 158.8573
# Epoch 23/100
# 23/23 - 0s - 9ms/step - loss: 40.4080 - val_loss: 140.5732
# Epoch 24/100
# 23/23 - 0s - 10ms/step - loss: 36.0501 - val_loss: 131.3714
# Epoch 25/100
# 23/23 - 0s - 9ms/step - loss: 34.6914 - val_loss: 135.6714
# Epoch 26/100
# 23/23 - 0s - 9ms/step - loss: 35.1958 - val_loss: 157.5068
# Epoch 27/100
# 23/23 - 0s - 9ms/step - loss: 32.3763 - val_loss: 124.3345
# Epoch 28/100
# 23/23 - 0s - 14ms/step - loss: 31.9521 - val_loss: 123.0572
# Epoch 29/100
# 23/23 - 0s - 10ms/step - loss: 28.9782 - val_loss: 152.4365
# Epoch 30/100
# 23/23 - 0s - 9ms/step - loss: 30.6376 - val_loss: 162.8456
# Epoch 31/100
# 23/23 - 0s - 8ms/step - loss: 26.2650 - val_loss: 149.9071
# Epoch 32/100
# 23/23 - 0s - 9ms/step - loss: 26.1781 - val_loss: 129.3505
# Epoch 33/100
# 23/23 - 0s - 8ms/step - loss: 24.1038 - val_loss: 136.6726
# Epoch 34/100
# 23/23 - 0s - 9ms/step - loss: 23.2231 - val_loss: 145.8737
# Epoch 35/100
# 23/23 - 0s - 9ms/step - loss: 24.7499 - val_loss: 135.2603
# Epoch 36/100
# 23/23 - 0s - 10ms/step - loss: 23.5780 - val_loss: 134.8360
# Epoch 37/100
# 23/23 - 0s - 11ms/step - loss: 22.1381 - val_loss: 116.0403
# Epoch 38/100
# 23/23 - 0s - 10ms/step - loss: 22.6808 - val_loss: 119.3085
# Epoch 39/100
# 23/23 - 0s - 10ms/step - loss: 21.3217 - val_loss: 113.1740
# Epoch 40/100
# 23/23 - 0s - 9ms/step - loss: 20.3194 - val_loss: 116.7691
# Epoch 41/100
# 23/23 - 0s - 9ms/step - loss: 21.6352 - val_loss: 137.6867
# Epoch 42/100
# 23/23 - 0s - 9ms/step - loss: 19.8820 - val_loss: 122.6648
# Epoch 43/100
# 23/23 - 0s - 8ms/step - loss: 19.1743 - val_loss: 125.7914
# Epoch 44/100
# 23/23 - 0s - 9ms/step - loss: 17.8798 - val_loss: 120.6193
# Epoch 45/100
# 23/23 - 0s - 8ms/step - loss: 17.6113 - val_loss: 106.3164
# Epoch 46/100
# 23/23 - 0s - 8ms/step - loss: 17.7178 - val_loss: 146.8472
# Epoch 47/100
# 23/23 - 0s - 8ms/step - loss: 18.8654 - val_loss: 131.8163
# Epoch 48/100
# 23/23 - 0s - 8ms/step - loss: 17.5205 - val_loss: 129.1708
# Epoch 49/100
# 23/23 - 0s - 9ms/step - loss: 17.9827 - val_loss: 129.5188
# Epoch 50/100
# 23/23 - 0s - 9ms/step - loss: 16.1642 - val_loss: 107.7641
# Epoch 51/100
# 23/23 - 0s - 9ms/step - loss: 16.3254 - val_loss: 119.2484
# Epoch 52/100
# 23/23 - 0s - 8ms/step - loss: 16.1046 - val_loss: 122.0591
# Epoch 53/100
# 23/23 - 0s - 9ms/step - loss: 16.4652 - val_loss: 120.0612
# Epoch 54/100
# 23/23 - 0s - 9ms/step - loss: 15.6916 - val_loss: 109.2641
# Epoch 55/100
# 23/23 - 0s - 9ms/step - loss: 15.6009 - val_loss: 114.0334
# Epoch 56/100
# 23/23 - 0s - 9ms/step - loss: 15.1119 - val_loss: 115.1647
# Epoch 57/100
# 23/23 - 0s - 12ms/step - loss: 15.0813 - val_loss: 143.0312
# Epoch 58/100
# 23/23 - 0s - 9ms/step - loss: 17.2647 - val_loss: 139.4963
# Epoch 59/100
# 23/23 - 0s - 9ms/step - loss: 16.0595 - val_loss: 127.3242
# Epoch 60/100
# 23/23 - 0s - 8ms/step - loss: 15.2579 - val_loss: 113.6127
# Epoch 61/100
# 23/23 - 0s - 13ms/step - loss: 14.0393 - val_loss: 123.8602
# Epoch 62/100
# 23/23 - 0s - 9ms/step - loss: 13.8446 - val_loss: 110.5271
# Epoch 63/100
# 23/23 - 0s - 9ms/step - loss: 13.5121 - val_loss: 128.0387
# Epoch 64/100
# 23/23 - 0s - 9ms/step - loss: 13.9828 - val_loss: 129.0531
# Epoch 65/100
# 23/23 - 0s - 9ms/step - loss: 13.4161 - val_loss: 107.8293
# Epoch 66/100
# 23/23 - 0s - 8ms/step - loss: 14.2929 - val_loss: 121.9001
# Epoch 67/100
# 23/23 - 0s - 9ms/step - loss: 13.2478 - val_loss: 109.4666
# Epoch 68/100
# 23/23 - 0s - 9ms/step - loss: 14.7468 - val_loss: 114.3785
# Epoch 69/100
# 23/23 - 0s - 10ms/step - loss: 14.1416 - val_loss: 116.9280
# Epoch 70/100
# 23/23 - 0s - 9ms/step - loss: 13.1570 - val_loss: 110.5562
# Epoch 71/100
# 23/23 - 0s - 8ms/step - loss: 12.8563 - val_loss: 108.2623
# Epoch 72/100
# 23/23 - 0s - 13ms/step - loss: 12.7546 - val_loss: 115.6152
# Epoch 73/100
# 23/23 - 0s - 8ms/step - loss: 13.9799 - val_loss: 110.6386
# Epoch 74/100
# 23/23 - 0s - 8ms/step - loss: 14.6001 - val_loss: 115.4911
# Epoch 75/100
# 23/23 - 0s - 8ms/step - loss: 13.8698 - val_loss: 124.5022
# Epoch 76/100
# 23/23 - 0s - 8ms/step - loss: 14.8052 - val_loss: 130.1213
# Epoch 77/100
# 23/23 - 0s - 8ms/step - loss: 15.1997 - val_loss: 124.9173
# Epoch 78/100
# 23/23 - 0s - 9ms/step - loss: 13.2235 - val_loss: 118.3356
# Epoch 79/100
# 23/23 - 0s - 10ms/step - loss: 13.1495 - val_loss: 124.1516
# Epoch 80/100
# 23/23 - 0s - 12ms/step - loss: 12.1204 - val_loss: 115.6696
# Epoch 81/100
# 23/23 - 0s - 13ms/step - loss: 12.8393 - val_loss: 103.7318
# Epoch 82/100
# 23/23 - 0s - 15ms/step - loss: 12.6770 - val_loss: 96.0566
# Epoch 83/100
# 23/23 - 0s - 10ms/step - loss: 12.4702 - val_loss: 119.3761
# Epoch 84/100
# 23/23 - 0s - 8ms/step - loss: 12.1403 - val_loss: 100.9172
# Epoch 85/100
# 23/23 - 0s - 9ms/step - loss: 16.0831 - val_loss: 92.1905
# Epoch 86/100
# 23/23 - 0s - 9ms/step - loss: 13.8913 - val_loss: 108.6669
# Epoch 87/100
# 23/23 - 0s - 9ms/step - loss: 11.7749 - val_loss: 103.4546
# Epoch 88/100
# 23/23 - 0s - 13ms/step - loss: 10.9799 - val_loss: 115.5992
# Epoch 89/100
# 23/23 - 0s - 14ms/step - loss: 11.2108 - val_loss: 127.1649
# Epoch 90/100
# 23/23 - 0s - 9ms/step - loss: 10.7997 - val_loss: 120.7371
# Epoch 91/100
# 23/23 - 0s - 9ms/step - loss: 12.3367 - val_loss: 120.2195
# Epoch 92/100
# 23/23 - 0s - 9ms/step - loss: 12.9861 - val_loss: 114.8371
# Epoch 93/100
# 23/23 - 0s - 14ms/step - loss: 13.4685 - val_loss: 107.7844
# Epoch 94/100
# 23/23 - 0s - 9ms/step - loss: 12.8822 - val_loss: 112.6416
# Epoch 95/100
# 23/23 - 0s - 9ms/step - loss: 10.7075 - val_loss: 107.1449
# Epoch 96/100
# 23/23 - 0s - 13ms/step - loss: 11.2367 - val_loss: 107.3612
# Epoch 97/100
# 23/23 - 0s - 9ms/step - loss: 10.7972 - val_loss: 121.9190
# Epoch 98/100
# 23/23 - 0s - 9ms/step - loss: 11.2815 - val_loss: 100.8198
# Epoch 99/100
# 23/23 - 0s - 9ms/step - loss: 11.4916 - val_loss: 105.4994
# Epoch 100/100
# 23/23 - 0s - 10ms/step - loss: 10.6238 - val_loss: 110.4066

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!-- Your answer is below:
# def regression_model():
#     input_colm = predictors_norm.shape[1] # Number of input features
#     # create model
#     model = Sequential()
#     model.add(Input(shape=(input_colm,)))  # Set the number of input features
#     model.add(Dense(50, activation='relu'))
#     model.add(Dense(50, activation='relu'))
#     model.add(Dense(50, activation='relu'))
#     model.add(Dense(50, activation='relu'))
#     model.add(Dense(50, activation='relu'))
#     model.add(Dense(1))  # Output layer
#
#     # compile model
#     model.compile(optimizer='adam', loss='mean_squared_error')
#     return model
#
# -->

# %% [markdown]
# <h3>Practice Exercise 2</h3>

# %% [markdown]
#  Train and evaluate the model simultaneously using the fit() method by reserving 10% of the data for validation and training the model for 100 epochs

# %%
model = regression_model()
model.fit(predictors_norm, target, validation_split=0.1, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 29/29 - 2s - 70ms/step - loss: 1553.0637 - val_loss: 1040.3975
# Epoch 2/100
# 29/29 - 0s - 9ms/step - loss: 784.5355 - val_loss: 202.6955
# Epoch 3/100
# 29/29 - 0s - 8ms/step - loss: 250.9787 - val_loss: 221.9721
# Epoch 4/100
# 29/29 - 0s - 8ms/step - loss: 211.2947 - val_loss: 194.2630
# Epoch 5/100
# 29/29 - 0s - 8ms/step - loss: 186.0793 - val_loss: 178.9950
# Epoch 6/100
# 29/29 - 0s - 8ms/step - loss: 171.4731 - val_loss: 168.6218
# Epoch 7/100
# 29/29 - 0s - 7ms/step - loss: 155.9676 - val_loss: 154.7937
# Epoch 8/100
# 29/29 - 0s - 8ms/step - loss: 142.7566 - val_loss: 140.9519
# Epoch 9/100
# 29/29 - 0s - 7ms/step - loss: 126.9320 - val_loss: 119.7447
# Epoch 10/100
# 29/29 - 0s - 7ms/step - loss: 110.7696 - val_loss: 115.6497
# Epoch 11/100
# 29/29 - 0s - 8ms/step - loss: 97.5827 - val_loss: 105.3333
# Epoch 12/100
# 29/29 - 0s - 7ms/step - loss: 83.7638 - val_loss: 89.1630
# Epoch 13/100
# 29/29 - 0s - 7ms/step - loss: 72.5824 - val_loss: 81.3327
# Epoch 14/100
# 29/29 - 0s - 8ms/step - loss: 69.9732 - val_loss: 76.7042
# Epoch 15/100
# 29/29 - 0s - 8ms/step - loss: 57.9172 - val_loss: 74.2315
# Epoch 16/100
# 29/29 - 0s - 7ms/step - loss: 50.0782 - val_loss: 60.1336
# Epoch 17/100
# 29/29 - 0s - 8ms/step - loss: 46.8336 - val_loss: 61.7428
# Epoch 18/100
# 29/29 - 0s - 7ms/step - loss: 42.7026 - val_loss: 53.8121
# Epoch 19/100
# 29/29 - 0s - 11ms/step - loss: 40.9402 - val_loss: 48.6390
# Epoch 20/100
# 29/29 - 0s - 8ms/step - loss: 38.7303 - val_loss: 50.0805
# Epoch 21/100
# 29/29 - 0s - 7ms/step - loss: 37.5259 - val_loss: 39.6161
# Epoch 22/100
# 29/29 - 0s - 8ms/step - loss: 35.0135 - val_loss: 45.4146
# Epoch 23/100
# 29/29 - 0s - 7ms/step - loss: 35.0492 - val_loss: 46.3427
# Epoch 24/100
# 29/29 - 0s - 8ms/step - loss: 33.3115 - val_loss: 36.5272
# Epoch 25/100
# 29/29 - 0s - 7ms/step - loss: 31.9256 - val_loss: 42.3355
# Epoch 26/100
# 29/29 - 0s - 11ms/step - loss: 31.6685 - val_loss: 48.3043
# Epoch 27/100
# 29/29 - 0s - 8ms/step - loss: 30.7931 - val_loss: 35.1061
# Epoch 28/100
# 29/29 - 0s - 7ms/step - loss: 29.7939 - val_loss: 30.8172
# Epoch 29/100
# 29/29 - 0s - 7ms/step - loss: 28.6423 - val_loss: 34.0644
# Epoch 30/100
# 29/29 - 0s - 8ms/step - loss: 26.3134 - val_loss: 34.8936
# Epoch 31/100
# 29/29 - 0s - 8ms/step - loss: 26.2837 - val_loss: 34.3281
# Epoch 32/100
# 29/29 - 0s - 7ms/step - loss: 25.1190 - val_loss: 34.8448
# Epoch 33/100
# 29/29 - 0s - 8ms/step - loss: 24.1524 - val_loss: 30.7042
# Epoch 34/100
# 29/29 - 0s - 7ms/step - loss: 23.7975 - val_loss: 28.4914
# Epoch 35/100
# 29/29 - 0s - 7ms/step - loss: 23.6639 - val_loss: 28.5123
# Epoch 36/100
# 29/29 - 0s - 7ms/step - loss: 23.3656 - val_loss: 32.9554
# Epoch 37/100
# 29/29 - 0s - 7ms/step - loss: 22.6234 - val_loss: 28.0277
# Epoch 38/100
# 29/29 - 0s - 11ms/step - loss: 23.6034 - val_loss: 26.6820
# Epoch 39/100
# 29/29 - 0s - 7ms/step - loss: 23.3285 - val_loss: 27.1047
# Epoch 40/100
# 29/29 - 0s - 11ms/step - loss: 21.4250 - val_loss: 28.4125
# Epoch 41/100
# 29/29 - 0s - 7ms/step - loss: 20.1931 - val_loss: 26.4735
# Epoch 42/100
# 29/29 - 0s - 7ms/step - loss: 21.7653 - val_loss: 25.1532
# Epoch 43/100
# 29/29 - 0s - 7ms/step - loss: 21.2835 - val_loss: 33.0661
# Epoch 44/100
# 29/29 - 0s - 7ms/step - loss: 21.3455 - val_loss: 31.2256
# Epoch 45/100
# 29/29 - 0s - 8ms/step - loss: 19.9050 - val_loss: 24.0334
# Epoch 46/100
# 29/29 - 0s - 7ms/step - loss: 19.2712 - val_loss: 29.0382
# Epoch 47/100
# 29/29 - 0s - 7ms/step - loss: 19.6282 - val_loss: 29.2338
# Epoch 48/100
# 29/29 - 0s - 7ms/step - loss: 19.0440 - val_loss: 29.5794
# Epoch 49/100
# 29/29 - 0s - 8ms/step - loss: 19.8317 - val_loss: 27.3454
# Epoch 50/100
# 29/29 - 0s - 10ms/step - loss: 18.5592 - val_loss: 27.5852
# Epoch 51/100
# 29/29 - 0s - 8ms/step - loss: 18.0833 - val_loss: 25.7162
# Epoch 52/100
# 29/29 - 0s - 7ms/step - loss: 17.8010 - val_loss: 24.3647
# Epoch 53/100
# 29/29 - 0s - 7ms/step - loss: 18.2857 - val_loss: 26.2990
# Epoch 54/100
# 29/29 - 0s - 8ms/step - loss: 17.3283 - val_loss: 23.5308
# Epoch 55/100
# 29/29 - 0s - 7ms/step - loss: 17.5618 - val_loss: 21.6687
# Epoch 56/100
# 29/29 - 0s - 7ms/step - loss: 17.3403 - val_loss: 22.8994
# Epoch 57/100
# 29/29 - 0s - 8ms/step - loss: 18.1636 - val_loss: 23.2081
# Epoch 58/100
# 29/29 - 0s - 10ms/step - loss: 16.7740 - val_loss: 22.7087
# Epoch 59/100
# 29/29 - 0s - 8ms/step - loss: 16.3628 - val_loss: 22.7708
# Epoch 60/100
# 29/29 - 0s - 8ms/step - loss: 16.7674 - val_loss: 24.2369
# Epoch 61/100
# 29/29 - 0s - 9ms/step - loss: 16.3819 - val_loss: 25.9389
# Epoch 62/100
# 29/29 - 0s - 8ms/step - loss: 16.7330 - val_loss: 21.0934
# Epoch 63/100
# 29/29 - 0s - 8ms/step - loss: 17.2800 - val_loss: 30.7415
# Epoch 64/100
# 29/29 - 0s - 8ms/step - loss: 18.5088 - val_loss: 22.1860
# Epoch 65/100
# 29/29 - 0s - 7ms/step - loss: 20.0660 - val_loss: 23.8820
# Epoch 66/100
# 29/29 - 0s - 7ms/step - loss: 15.9722 - val_loss: 22.8727
# Epoch 67/100
# 29/29 - 0s - 7ms/step - loss: 15.9475 - val_loss: 24.8560
# Epoch 68/100
# 29/29 - 0s - 7ms/step - loss: 16.2078 - val_loss: 22.8140
# Epoch 69/100
# 29/29 - 0s - 7ms/step - loss: 15.0137 - val_loss: 21.7231
# Epoch 70/100
# 29/29 - 0s - 8ms/step - loss: 14.9918 - val_loss: 20.3748
# Epoch 71/100
# 29/29 - 0s - 7ms/step - loss: 15.6169 - val_loss: 21.0458
# Epoch 72/100
# 29/29 - 0s - 7ms/step - loss: 15.4385 - val_loss: 20.2889
# Epoch 73/100
# 29/29 - 0s - 7ms/step - loss: 15.2338 - val_loss: 21.3370
# Epoch 74/100
# 29/29 - 0s - 7ms/step - loss: 15.4479 - val_loss: 21.7942
# Epoch 75/100
# 29/29 - 0s - 7ms/step - loss: 15.6085 - val_loss: 20.3581
# Epoch 76/100
# 29/29 - 0s - 7ms/step - loss: 14.9389 - val_loss: 20.7292
# Epoch 77/100
# 29/29 - 0s - 7ms/step - loss: 15.4225 - val_loss: 20.4212
# Epoch 78/100
# 29/29 - 0s - 7ms/step - loss: 14.9272 - val_loss: 20.8265
# Epoch 79/100
# 29/29 - 0s - 7ms/step - loss: 17.3388 - val_loss: 34.4831
# Epoch 80/100
# 29/29 - 0s - 11ms/step - loss: 16.1381 - val_loss: 21.4376
# Epoch 81/100
# 29/29 - 0s - 7ms/step - loss: 14.9969 - val_loss: 23.7103
# Epoch 82/100
# 29/29 - 0s - 7ms/step - loss: 15.4347 - val_loss: 23.5311
# Epoch 83/100
# 29/29 - 0s - 10ms/step - loss: 14.7572 - val_loss: 22.3154
# Epoch 84/100
# 29/29 - 0s - 7ms/step - loss: 14.1141 - val_loss: 23.2413
# Epoch 85/100
# 29/29 - 0s - 11ms/step - loss: 13.8978 - val_loss: 22.5010
# Epoch 86/100
# 29/29 - 0s - 7ms/step - loss: 14.0062 - val_loss: 21.7832
# Epoch 87/100
# 29/29 - 0s - 7ms/step - loss: 13.4398 - val_loss: 23.4858
# Epoch 88/100
# 29/29 - 0s - 7ms/step - loss: 15.0548 - val_loss: 23.2542
# Epoch 89/100
# 29/29 - 0s - 8ms/step - loss: 14.5820 - val_loss: 22.3024
# Epoch 90/100
# 29/29 - 0s - 8ms/step - loss: 13.1538 - val_loss: 21.2882
# Epoch 91/100
# 29/29 - 0s - 7ms/step - loss: 13.6928 - val_loss: 29.0184
# Epoch 92/100
# 29/29 - 0s - 8ms/step - loss: 13.6808 - val_loss: 20.0885
# Epoch 93/100
# 29/29 - 0s - 8ms/step - loss: 13.0907 - val_loss: 20.9985
# Epoch 94/100
# 29/29 - 0s - 7ms/step - loss: 13.0143 - val_loss: 24.3365
# Epoch 95/100
# 29/29 - 0s - 8ms/step - loss: 13.5591 - val_loss: 18.6666
# Epoch 96/100
# 29/29 - 0s - 7ms/step - loss: 14.1248 - val_loss: 20.2768
# Epoch 97/100
# 29/29 - 0s - 7ms/step - loss: 13.6518 - val_loss: 20.3997
# Epoch 98/100
# 29/29 - 0s - 8ms/step - loss: 12.6136 - val_loss: 19.8555
# Epoch 99/100
# 29/29 - 0s - 11ms/step - loss: 12.9301 - val_loss: 27.7592
# Epoch 100/100
# 29/29 - 0s - 8ms/step - loss: 13.5616 - val_loss: 19.5778

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!-- Your answer is below:
# # build the model
# model = regression_model()
# model.fit(predictors_norm, target, validation_split=0.1, epochs=100, verbose=2)
#
# -->

# %% [markdown]
# Based on the results, we notice that:
#
# - Adding more hidden layers to the model increases its capacity to learn and represent complex relationships within the data. This allows the model to better identify, as a result, the model becomes more effective at fitting the training data and potentially improving its predictions.
# - By reducing the proportion of data set aside for validation and using a larger portion for training, the model has access to more examples to learn from. This additional training data helps the model improve its understanding of the underlying trends, which can lead to better overall performance.

# %% [markdown]
# ### Thank you for completing this lab!
#
# This notebook was created by [Alex Aklson](https://www.linkedin.com/in/aklson/). I hope you found this lab interesting and educational. Feel free to contact me if you have any questions!

# %% [markdown]
# <!--
# ## Change Log
#
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2024-11-20  | 3.0  | Aman  |  Updated the library versions to current |
# | 2020-09-21  | 2.0  | Srishti  |  Migrated Lab to Markdown and added to course repo in GitLab |
#
#
#
# <hr>
#
# ## <h3 align="center"> © IBM Corporation. All rights reserved. <h3/>

# %% [markdown]
# ## <h3 align="center"> &#169; IBM Corporation. All rights reserved. <h3/>
